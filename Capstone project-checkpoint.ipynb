# %% [markdown]
# # Housing price predictive model

# %%
pip install dill
# Out:
# Collecting dill
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
# Installing collected packages: dill
# Successfully installed dill-0.3.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing libraries for handling data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import dill

# %%
#Import data
url= 'Cook_County_Assessor_s_Residential_Modeling_Characteristics__Chicago_.csv'

df = pd.read_csv(url)
# Out:
# C:\Users\Yerlan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3,4,5,21,23,24,25,28,29,30,31,33,36,37,38,39,40,41,43,44,45,46,47,48,49,66,67,68) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Storing data
with open('df.pkl', 'wb') as file:
    dill.dump(df, file)

# %%
#Read data
with open('df.pkl', 'rb') as file:
    df = dill.load(file)

# %% [markdown]
# # Data Wrangling

# %%
df.shape
# Out:
# (678656, 80)

# %%
# Get a summary of all features in the data and their types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678656 entries, 0 to 678655
# Data columns (total 80 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Property Index Number                      678656 non-null  object
#  1   Assessment Triad                           678656 non-null  object
#  2   Property Class                             678656 non-null  int64
#  3   Property Address                           438038 non-null  object
#  4   Property Apartment Num.                    53875 non-null   object
#  5   Property City                              438038 non-null  object
#  6   Township Name                              678656 non-null  object
#  7   Township Code                              678656 non-null  int64
#  8   Neighborhood Code                          678656 non-null  int64
#  9   Township Neighborhood Only                 678656 non-null  int64
#  10  Modeling Group                             678656 non-null  object
#  11  Proportion Assessed                        678656 non-null  float64
#  12  Key PIN                                    250654 non-null  object
#  13  Multi Code Indicator                       678656 non-null  int64
#  14  Multi Code                                 678162 non-null  float64
#  15  Number of Active 288s (HIEs)               438728 non-null  float64
#  16  Number of Ended 288s (HIEs)                438728 non-null  float64
#  17  Sale Date                                  78156 non-null   object
#  18  Sale Price                                 78156 non-null   float64
#  19  Sale Document Number                       78156 non-null   float64
#  20  Land Square Feet                           438728 non-null  float64
#  21  Large Home Indicator                       438728 non-null  object
#  22  Age                                        678656 non-null  int64
#  23  Apartments                                 125141 non-null  object
#  24  Wall Material                              438298 non-null  object
#  25  Roof Material                              438297 non-null  object
#  26  Rooms                                      438728 non-null  float64
#  27  Bedrooms                                   438728 non-null  float64
#  28  Basement                                   438297 non-null  object
#  29  Basement Finish                            438297 non-null  object
#  30  Central Heating                            438297 non-null  object
#  31  Central Air Conditioning                   438298 non-null  object
#  32  Fireplaces                                 438299 non-null  float64
#  33  Attic Type                                 438297 non-null  object
#  34  Full Baths                                 438728 non-null  float64
#  35  Half Baths                                 438728 non-null  float64
#  36  Design Plan                                310120 non-null  object
#  37  Cathedral Ceiling                          213503 non-null  object
#  38  Garage 1 Size                              438299 non-null  object
#  39  Garage 1 Material                          327970 non-null  object
#  40  Garage 1 Attached                          327968 non-null  object
#  41  Garage 1 Area                              327965 non-null  object
#  42  Building Square Feet                       438728 non-null  float64
#  43  Repair Condition                           438297 non-null  object
#  44  Use                                        438299 non-null  object
#  45  Type of Residence                          438299 non-null  object
#  46  Attic Finish                               164273 non-null  object
#  47  Renovation                                 2278 non-null    object
#  48  Porch                                      113755 non-null  object
#  49  Property Zip Code                          438038 non-null  object
#  50  Tract GEOID                                678656 non-null  int64
#  51  Municipality FIPS Code                     677844 non-null  float64
#  52  Municipality Name                          677844 non-null  object
#  53  O'Hare Noise Indicator                     678656 non-null  int64
#  54  FEMA Floodplain                            678656 non-null  int64
#  55  Flood Risk Factor                          678656 non-null  int64
#  56  Flood Risk Direction                       678656 non-null  int64
#  57  Road Proximity < 100 Feet                  678656 non-null  int64
#  58  Road Proximity 101 - 300 Feet              678656 non-null  int64
#  59  Elementary/Middle School District          678656 non-null  object
#  60  High School District                       678656 non-null  object
#  61  Longitude                                  678656 non-null  float64
#  62  Latitude                                   678656 non-null  float64
#  63  geoposition                                678656 non-null  object
#  64  Tax Rate                                   678656 non-null  float64
#  65  Tract Median Income                        678656 non-null  int64
#  66  Condo Model: Building PIN                  239928 non-null  object
#  67  Condo Model: Modeled Unit Strata (of 10)   222135 non-null  object
#  68  Condo Model: Modeled Unit Strata (of 300)  222135 non-null  object
#  69  Modeled Sale Year                          678656 non-null  int64
#  70  Modeled Sale Month of Year                 678656 non-null  object
#  71  Modeled Sale Day of Year                   678656 non-null  int64
#  72  Modeled Sale Week of Year                  678656 non-null  int64
#  73  Modeled Sale Quarter of Year               678656 non-null  object
#  74  Modeled Sale Quarter                       678656 non-null  int64
#  75  Modeled Sale Month                         678656 non-null  int64
#  76  Modeled Sale Week                          678656 non-null  int64
#  77  Modeled Sale Day                           678656 non-null  int64
#  78  Modeled Sale During School Year            678656 non-null  bool
#  79  Modeled Sale During Holidays               678656 non-null  bool
# dtypes: bool(2), float64(17), int64(21), object(40)
# memory usage: 405.2+ MB

# %%
df = df[df['Sale Price'].notna()]

# %%
#Dropping unnecessary columns
df = df.drop(df.columns[66:], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78156 entries, 8 to 678636
# Data columns (total 66 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Property Index Number              78156 non-null  object
#  1   Assessment Triad                   78156 non-null  object
#  2   Property Class                     78156 non-null  int64
#  3   Property Address                   45550 non-null  object
#  4   Property Apartment Num.            5984 non-null   object
#  5   Property City                      45550 non-null  object
#  6   Township Name                      78156 non-null  object
#  7   Township Code                      78156 non-null  int64
#  8   Neighborhood Code                  78156 non-null  int64
#  9   Township Neighborhood Only         78156 non-null  int64
#  10  Modeling Group                     78156 non-null  object
#  11  Proportion Assessed                78156 non-null  float64
#  12  Key PIN                            32656 non-null  object
#  13  Multi Code Indicator               78156 non-null  int64
#  14  Multi Code                         78134 non-null  float64
#  15  Number of Active 288s (HIEs)       45577 non-null  float64
#  16  Number of Ended 288s (HIEs)        45577 non-null  float64
#  17  Sale Date                          78156 non-null  object
#  18  Sale Price                         78156 non-null  float64
#  19  Sale Document Number               78156 non-null  float64
#  20  Land Square Feet                   45577 non-null  float64
#  21  Large Home Indicator               45577 non-null  object
#  22  Age                                78156 non-null  int64
#  23  Apartments                         12625 non-null  object
#  24  Wall Material                      45571 non-null  object
#  25  Roof Material                      45571 non-null  object
#  26  Rooms                              45577 non-null  float64
#  27  Bedrooms                           45577 non-null  float64
#  28  Basement                           45571 non-null  object
#  29  Basement Finish                    45571 non-null  object
#  30  Central Heating                    45571 non-null  object
#  31  Central Air Conditioning           45571 non-null  object
#  32  Fireplaces                         45572 non-null  float64
#  33  Attic Type                         45571 non-null  object
#  34  Full Baths                         45577 non-null  float64
#  35  Half Baths                         45577 non-null  float64
#  36  Design Plan                        33228 non-null  object
#  37  Cathedral Ceiling                  23928 non-null  object
#  38  Garage 1 Size                      45572 non-null  object
#  39  Garage 1 Material                  34453 non-null  object
#  40  Garage 1 Attached                  34452 non-null  object
#  41  Garage 1 Area                      34452 non-null  object
#  42  Building Square Feet               45577 non-null  float64
#  43  Repair Condition                   45571 non-null  object
#  44  Use                                45572 non-null  object
#  45  Type of Residence                  45571 non-null  object
#  46  Attic Finish                       16506 non-null  object
#  47  Renovation                         313 non-null    object
#  48  Porch                              11832 non-null  object
#  49  Property Zip Code                  45550 non-null  object
#  50  Tract GEOID                        78156 non-null  int64
#  51  Municipality FIPS Code             78105 non-null  float64
#  52  Municipality Name                  78105 non-null  object
#  53  O'Hare Noise Indicator             78156 non-null  int64
#  54  FEMA Floodplain                    78156 non-null  int64
#  55  Flood Risk Factor                  78156 non-null  int64
#  56  Flood Risk Direction               78156 non-null  int64
#  57  Road Proximity < 100 Feet          78156 non-null  int64
#  58  Road Proximity 101 - 300 Feet      78156 non-null  int64
#  59  Elementary/Middle School District  78156 non-null  object
#  60  High School District               78156 non-null  object
#  61  Longitude                          78156 non-null  float64
#  62  Latitude                           78156 non-null  float64
#  63  geoposition                        78156 non-null  object
#  64  Tax Rate                           78156 non-null  float64
#  65  Tract Median Income                78156 non-null  int64
# dtypes: float64(17), int64(14), object(35)
# memory usage: 40.0+ MB

# %%
with open('data.pkl', 'wb') as file:
    dill.dump(df, file)

# %%
with open('data.pkl', 'rb') as file:
    data = dill.load(file)

# %%
print(data.shape)
# Out:
# (78156, 66)

# %% [markdown]
# Here, I am checking % of NaN values present in each feature

# %%
feautres_na = [features for features in data.columns if data[features].isnull().sum()>1]

# %%
feautres_na
# Out:
# ['Property Address',
#  'Property Apartment Num.',
#  'Property City',
#  'Key PIN',
#  'Multi Code',
#  'Number of Active 288s (HIEs)',
#  'Number of Ended 288s (HIEs)',
#  'Land Square Feet',
#  'Large Home Indicator',
#  'Apartments',
#  'Wall Material',
#  'Roof Material',
#  'Rooms',
#  'Bedrooms',
#  'Basement',
#  'Basement Finish',
#  'Central Heating',
#  'Central Air Conditioning',
#  'Fireplaces',
#  'Attic Type',
#  'Full Baths',
#  'Half Baths',
#  'Design Plan',
#  'Cathedral Ceiling',
#  'Garage 1 Size',
#  'Garage 1 Material',
#  'Garage 1 Attached',
#  'Garage 1 Area',
#  'Building Square Feet',
#  'Repair Condition',
#  'Use',
#  'Type of Residence',
#  'Attic Finish',
#  'Renovation',
#  'Porch',
#  'Property Zip Code',
#  'Municipality FIPS Code',
#  'Municipality Name']

# %%
for features in feautres_na:
    print(features,np.round(data[features].isnull().mean(),4),'%')
# Out:
# Property Address 0.4172 %
# Property Apartment Num. 0.9234 %
# Property City 0.4172 %
# Key PIN 0.5822 %
# Multi Code 0.0003 %
# Number of Active 288s (HIEs) 0.4168 %
# Number of Ended 288s (HIEs) 0.4168 %
# Land Square Feet 0.4168 %
# Large Home Indicator 0.4168 %
# Apartments 0.8385 %
# Wall Material 0.4169 %
# Roof Material 0.4169 %
# Rooms 0.4168 %
# Bedrooms 0.4168 %
# Basement 0.4169 %
# Basement Finish 0.4169 %
# Central Heating 0.4169 %
# Central Air Conditioning 0.4169 %
# Fireplaces 0.4169 %
# Attic Type 0.4169 %
# Full Baths 0.4168 %
# Half Baths 0.4168 %
# Design Plan 0.5749 %
# Cathedral Ceiling 0.6938 %
# Garage 1 Size 0.4169 %
# Garage 1 Material 0.5592 %
# Garage 1 Attached 0.5592 %
# Garage 1 Area 0.5592 %
# Building Square Feet 0.4168 %
# Repair Condition 0.4169 %
# Use 0.4169 %
# Type of Residence 0.4169 %
# Attic Finish 0.7888 %
# Renovation 0.996 %
# Porch 0.8486 %
# Property Zip Code 0.4172 %
# Municipality FIPS Code 0.0007 %
# Municipality Name 0.0007 %

# %% [markdown]
# After consideration, I decided to drop columns with more that 45% missing values

# %%
more_than_45_percent_misssing_value_features = [features for features in feautres_na if (np.round(data[features].isnull().mean(),4)) > 0.45]

# %%
more_than_45_percent_misssing_value_features
# Out:
# ['Property Apartment Num.',
#  'Key PIN',
#  'Apartments',
#  'Design Plan',
#  'Cathedral Ceiling',
#  'Garage 1 Material',
#  'Garage 1 Attached',
#  'Garage 1 Area',
#  'Attic Finish',
#  'Renovation',
#  'Porch']

# %%
print("Rows     : ", data.shape[0])
print("Columns  : ", data.shape[1])
print("\nFeatures : \n", data.columns.tolist())
print("\nMissing values :  ", data.isnull().sum().values.sum())
print("\nUnique values :  \n", data.nunique())
# Out:
# Rows     :  78156
# Columns  :  66
#
# Features :
#  ['Property Index Number', 'Assessment Triad', 'Property Class', 'Property Address', 'Property Apartment Num.', 'Property City', 'Township Name', 'Township Code', 'Neighborhood Code', 'Township Neighborhood Only', 'Modeling Group', 'Proportion Assessed', 'Key PIN', 'Multi Code Indicator', 'Multi Code', 'Number of Active 288s (HIEs)', 'Number of Ended 288s (HIEs)', 'Sale Date', 'Sale Price', 'Sale Document Number', 'Land Square Feet', 'Large Home Indicator', 'Age', 'Apartments', 'Wall Material', 'Roof Material', 'Rooms', 'Bedrooms', 'Basement', 'Basement Finish', 'Central Heating', 'Central Air Conditioning', 'Fireplaces', 'Attic Type', 'Full Baths', 'Half Baths', 'Design Plan', 'Cathedral Ceiling', 'Garage 1 Size', 'Garage 1 Material', 'Garage 1 Attached', 'Garage 1 Area', 'Building Square Feet', 'Repair Condition', 'Use', 'Type of Residence', 'Attic Finish', 'Renovation', 'Porch', 'Property Zip Code', 'Tract GEOID', 'Municipality FIPS Code', 'Municipality Name', "O'Hare Noise Indicator", 'FEMA Floodplain', 'Flood Risk Factor', 'Flood Risk Direction', 'Road Proximity < 100 Feet', 'Road Proximity 101 - 300 Feet', 'Elementary/Middle School District', 'High School District', 'Longitude', 'Latitude', 'geoposition', 'Tax Rate', 'Tract Median Income']
#
# Missing values :   1401457
#
# Unique values :
#  Property Index Number      78151
# Assessment Triad               1
# Property Class                16
# Property Address           45083
# Property Apartment Num.      224
#                            ...
# Longitude                  54613
# Latitude                   54613
# geoposition                54613
# Tax Rate                      74
# Tract Median Income          784
# Length: 66, dtype: int64

# %%
# Get a summary of all features in the data and their types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78156 entries, 8 to 678636
# Data columns (total 66 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Property Index Number              78156 non-null  object
#  1   Assessment Triad                   78156 non-null  object
#  2   Property Class                     78156 non-null  int64
#  3   Property Address                   45550 non-null  object
#  4   Property Apartment Num.            5984 non-null   object
#  5   Property City                      45550 non-null  object
#  6   Township Name                      78156 non-null  object
#  7   Township Code                      78156 non-null  int64
#  8   Neighborhood Code                  78156 non-null  int64
#  9   Township Neighborhood Only         78156 non-null  int64
#  10  Modeling Group                     78156 non-null  object
#  11  Proportion Assessed                78156 non-null  float64
#  12  Key PIN                            32656 non-null  object
#  13  Multi Code Indicator               78156 non-null  int64
#  14  Multi Code                         78134 non-null  float64
#  15  Number of Active 288s (HIEs)       45577 non-null  float64
#  16  Number of Ended 288s (HIEs)        45577 non-null  float64
#  17  Sale Date                          78156 non-null  object
#  18  Sale Price                         78156 non-null  float64
#  19  Sale Document Number               78156 non-null  float64
#  20  Land Square Feet                   45577 non-null  float64
#  21  Large Home Indicator               45577 non-null  object
#  22  Age                                78156 non-null  int64
#  23  Apartments                         12625 non-null  object
#  24  Wall Material                      45571 non-null  object
#  25  Roof Material                      45571 non-null  object
#  26  Rooms                              45577 non-null  float64
#  27  Bedrooms                           45577 non-null  float64
#  28  Basement                           45571 non-null  object
#  29  Basement Finish                    45571 non-null  object
#  30  Central Heating                    45571 non-null  object
#  31  Central Air Conditioning           45571 non-null  object
#  32  Fireplaces                         45572 non-null  float64
#  33  Attic Type                         45571 non-null  object
#  34  Full Baths                         45577 non-null  float64
#  35  Half Baths                         45577 non-null  float64
#  36  Design Plan                        33228 non-null  object
#  37  Cathedral Ceiling                  23928 non-null  object
#  38  Garage 1 Size                      45572 non-null  object
#  39  Garage 1 Material                  34453 non-null  object
#  40  Garage 1 Attached                  34452 non-null  object
#  41  Garage 1 Area                      34452 non-null  object
#  42  Building Square Feet               45577 non-null  float64
#  43  Repair Condition                   45571 non-null  object
#  44  Use                                45572 non-null  object
#  45  Type of Residence                  45571 non-null  object
#  46  Attic Finish                       16506 non-null  object
#  47  Renovation                         313 non-null    object
#  48  Porch                              11832 non-null  object
#  49  Property Zip Code                  45550 non-null  object
#  50  Tract GEOID                        78156 non-null  int64
#  51  Municipality FIPS Code             78105 non-null  float64
#  52  Municipality Name                  78105 non-null  object
#  53  O'Hare Noise Indicator             78156 non-null  int64
#  54  FEMA Floodplain                    78156 non-null  int64
#  55  Flood Risk Factor                  78156 non-null  int64
#  56  Flood Risk Direction               78156 non-null  int64
#  57  Road Proximity < 100 Feet          78156 non-null  int64
#  58  Road Proximity 101 - 300 Feet      78156 non-null  int64
#  59  Elementary/Middle School District  78156 non-null  object
#  60  High School District               78156 non-null  object
#  61  Longitude                          78156 non-null  float64
#  62  Latitude                           78156 non-null  float64
#  63  geoposition                        78156 non-null  object
#  64  Tax Rate                           78156 non-null  float64
#  65  Tract Median Income                78156 non-null  int64
# dtypes: float64(17), int64(14), object(35)
# memory usage: 40.0+ MB

# %%
# Remove duplicates from data, if any
data.duplicated(subset=None, keep="first")
print("Housing Data", data.shape)
# Out:
# Housing Data (78156, 66)

# %%
# next I'll check for missing values in data
pd.options.display.min_rows = 100
data.isnull().sum().sort_values(ascending=False)
# Out:
# Renovation                           77843
# Property Apartment Num.              72172
# Porch                                66324
# Apartments                           65531
# Attic Finish                         61650
# Cathedral Ceiling                    54228
# Key PIN                              45500
# Design Plan                          44928
# Garage 1 Area                        43704
# Garage 1 Attached                    43704
# Garage 1 Material                    43703
# Property Zip Code                    32606
# Property City                        32606
# Property Address                     32606
# Repair Condition                     32585
# Type of Residence                    32585
# Central Air Conditioning             32585
# Central Heating                      32585
# Basement Finish                      32585
# Basement                             32585
# Wall Material                        32585
# Attic Type                           32585
# Roof Material                        32585
# Use                                  32584
# Garage 1 Size                        32584
# Fireplaces                           32584
# Number of Ended 288s (HIEs)          32579
# Building Square Feet                 32579
# Large Home Indicator                 32579
# Half Baths                           32579
#                                      ...
# Municipality FIPS Code                  51
# Multi Code                              22
# Flood Risk Direction                     0
# Tax Rate                                 0
# geoposition                              0
# Latitude                                 0
# Longitude                                0
# Elementary/Middle School District        0
# High School District                     0
# Road Proximity 101 - 300 Feet            0
# Road Proximity < 100 Feet                0
# FEMA Floodplain                          0
# Flood Risk Factor                        0
# O'Hare Noise Indicator                   0
# Property Index Number                    0
# Tract GEOID                              0
# Assessment Triad                         0
# Age                                      0
# Sale Document Number                     0
# Sale Price                               0
# Sale Date                                0
# Multi Code Indicator                     0
# Proportion Assessed                      0
# Modeling Group                           0
# Township Neighborhood Only               0
# Neighborhood Code                        0
# Township Code                            0
# Township Name                            0
# Property Class                           0
# Tract Median Income                      0
# Length: 66, dtype: int64

# %%
feautres_na = [features for features in data.columns if data[features].isnull().sum()>1]
len(feautres_na)
# Out:
# 38

# %%
feautres_na
# Out:
# ['Property Address',
#  'Property Apartment Num.',
#  'Property City',
#  'Key PIN',
#  'Multi Code',
#  'Number of Active 288s (HIEs)',
#  'Number of Ended 288s (HIEs)',
#  'Land Square Feet',
#  'Large Home Indicator',
#  'Apartments',
#  'Wall Material',
#  'Roof Material',
#  'Rooms',
#  'Bedrooms',
#  'Basement',
#  'Basement Finish',
#  'Central Heating',
#  'Central Air Conditioning',
#  'Fireplaces',
#  'Attic Type',
#  'Full Baths',
#  'Half Baths',
#  'Design Plan',
#  'Cathedral Ceiling',
#  'Garage 1 Size',
#  'Garage 1 Material',
#  'Garage 1 Attached',
#  'Garage 1 Area',
#  'Building Square Feet',
#  'Repair Condition',
#  'Use',
#  'Type of Residence',
#  'Attic Finish',
#  'Renovation',
#  'Porch',
#  'Property Zip Code',
#  'Municipality FIPS Code',
#  'Municipality Name']

# %%
data[feautres_na]
# Out:
#        Property Address Property Apartment Num. Property City  \
# 8                   NaN                     NaN           NaN
# 33                  NaN                     NaN           NaN
# 42                  NaN                     NaN           NaN
# 43                  NaN                     NaN           NaN
# 52                  NaN                     NaN           NaN
# 68                  NaN                     NaN           NaN
# 77                  NaN                     NaN           NaN
# 97                  NaN                     NaN           NaN
# 103                 NaN                     NaN           NaN
# 106                 NaN                     NaN           NaN
# 109                 NaN                     NaN           NaN
# 118                 NaN                     NaN           NaN
# 139                 NaN                     NaN           NaN
# 144                 NaN                     NaN           NaN
# 158                 NaN                     NaN           NaN
# 162                 NaN                     NaN           NaN
# 165                 NaN                     NaN           NaN
# 176                 NaN                     NaN           NaN
# 177                 NaN                     NaN           NaN
# 184                 NaN                     NaN           NaN
# 194                 NaN                     NaN           NaN
# 202                 NaN                     NaN           NaN
# 222                 NaN                     NaN           NaN
# 229                 NaN                     NaN           NaN
# 239                 NaN                     NaN           NaN
# 243                 NaN                     NaN           NaN
# 258                 NaN                     NaN           NaN
# 273                 NaN                     NaN           NaN
# 286                 NaN                     NaN           NaN
# 289                 NaN                     NaN           NaN
# ...                 ...                     ...           ...
# 678429              NaN                     NaN           NaN
# 678434              NaN                     NaN           NaN
# 678437              NaN                     NaN           NaN
# 678439              NaN                     NaN           NaN
# 678455              NaN                     NaN           NaN
# 678467              NaN                     NaN           NaN
# 678472              NaN                     NaN           NaN
# 678476              NaN                     NaN           NaN
# 678481              NaN                     NaN           NaN
# 678484              NaN                     NaN           NaN
# 678496              NaN                     NaN           NaN
# 678498              NaN                     NaN           NaN
# 678503              NaN                     NaN           NaN
# 678506              NaN                     NaN           NaN
# 678518              NaN                     NaN           NaN
# 678532              NaN                     NaN           NaN
# 678540              NaN                     NaN           NaN
# 678547              NaN                     NaN           NaN
# 678553              NaN                     NaN           NaN
# 678555              NaN                     NaN           NaN
# 678567              NaN                     NaN           NaN
# 678577              NaN                     NaN           NaN
# 678578              NaN                     NaN           NaN
# 678586              NaN                     NaN           NaN
# 678610              NaN                     NaN           NaN
# 678615              NaN                     NaN           NaN
# 678617              NaN                     NaN           NaN
# 678620              NaN                     NaN           NaN
# 678622              NaN                     NaN           NaN
# 678636              NaN                     NaN           NaN
#
#                    Key PIN  Multi Code  Number of Active 288s (HIEs)  \
# 8       13-24-125-042-1007         2.0                           NaN
# 33      14-08-102-057-1001         2.0                           NaN
# 42      19-20-114-031-1012         2.0                           NaN
# 43      17-16-128-007-1001         2.0                           NaN
# 52      14-20-213-024-1008         2.0                           NaN
# 68      13-18-409-074-1001         2.0                           NaN
# 77      14-17-403-056-1074         2.0                           NaN
# 97      10-25-328-008-1001         2.0                           NaN
# 103     17-18-116-033-1001         2.0                           NaN
# 106     17-22-110-100-1204         2.0                           NaN
# 109     14-08-407-022-1025         2.0                           NaN
# 118     17-05-308-132-1002         2.0                           NaN
# 139     17-10-208-020-1208         2.0                           NaN
# 144     16-12-419-055-1003         2.0                           NaN
# 158     17-18-127-063-1001         2.0                           NaN
# 162     09-36-112-029-1001         2.0                           NaN
# 165     13-11-306-019-1001         2.0                           NaN
# 176     14-05-215-017-1172         2.0                           NaN
# 177     14-33-306-065-1001         2.0                           NaN
# 184     20-24-419-018-1001         2.0                           NaN
# 194     14-16-301-041-1218         2.0                           NaN
# 202     14-05-311-061-1001         2.0                           NaN
# 222     14-21-110-020-1116         2.0                           NaN
# 229     14-07-207-043-1009         2.0                           NaN
# 239     17-03-103-032-1001         2.0                           NaN
# 243     14-19-424-017-1015         2.0                           NaN
# 258     17-09-302-010-1001         2.0                           NaN
# 273     14-21-110-048-1590         2.0                           NaN
# 286     17-05-320-068-1001         2.0                           NaN
# 289     14-32-414-072-1001         2.0                           NaN
# ...                    ...         ...                           ...
# 678429  14-17-414-031-1022         2.0                           NaN
# 678434  14-31-305-060-1001         2.0                           NaN
# 678437  12-11-121-037-1001         2.0                           NaN
# 678439  20-11-418-011-1021         2.0                           NaN
# 678455  12-24-216-050-1001         2.0                           NaN
# 678467  20-24-420-030-1022         2.0                           NaN
# 678472  17-07-201-060-1006         2.0                           NaN
# 678476  14-08-124-057-1005         2.0                           NaN
# 678481  17-21-408-029-1007         2.0                           NaN
# 678484  14-05-407-016-1063         2.0                           NaN
# 678496  14-33-414-044-1146         2.0                           NaN
# 678498  14-29-210-053-1001         2.0                           NaN
# 678503  17-05-308-113-1001         2.0                           NaN
# 678506  13-36-207-028-1044         2.0                           NaN
# 678518  17-15-101-026-1612         2.0                           NaN
# 678532  14-31-213-054-1001         2.0                           NaN
# 678540  14-33-414-044-1110         2.0                           NaN
# 678547  20-11-104-048-1001         2.0                           NaN
# 678553  17-03-227-024-1001         2.0                           NaN
# 678555  14-21-109-017-1039         2.0                           NaN
# 678567  12-24-232-029-1027         2.0                           NaN
# 678577  20-15-305-038-1001         2.0                           NaN
# 678578  14-05-203-011-1123         2.0                           NaN
# 678586  17-06-229-070-1001         2.0                           NaN
# 678610  13-12-205-058-1001         2.0                           NaN
# 678615  14-30-117-042-1017         2.0                           NaN
# 678617  20-23-116-034-1001         2.0                           NaN
# 678620  20-23-109-052-1008         2.0                           NaN
# 678622  14-08-413-044-1001         2.0                           NaN
# 678636  11-31-303-069-1003         2.0                           NaN
#
#         Number of Ended 288s (HIEs)  Land Square Feet Large Home Indicator  \
# 8                               NaN               NaN                  NaN
# 33                              NaN               NaN                  NaN
# 42                              NaN               NaN                  NaN
# 43                              NaN               NaN                  NaN
# 52                              NaN               NaN                  NaN
# 68                              NaN               NaN                  NaN
# 77                              NaN               NaN                  NaN
# 97                              NaN               NaN                  NaN
# 103                             NaN               NaN                  NaN
# 106                             NaN               NaN                  NaN
# 109                             NaN               NaN                  NaN
# 118                             NaN               NaN                  NaN
# 139                             NaN               NaN                  NaN
# 144                             NaN               NaN                  NaN
# 158                             NaN               NaN                  NaN
# 162                             NaN               NaN                  NaN
# 165                             NaN               NaN                  NaN
# 176                             NaN               NaN                  NaN
# 177                             NaN               NaN                  NaN
# 184                             NaN               NaN                  NaN
# 194                             NaN               NaN                  NaN
# 202                             NaN               NaN                  NaN
# 222                             NaN               NaN                  NaN
# 229                             NaN               NaN                  NaN
# 239                             NaN               NaN                  NaN
# 243                             NaN               NaN                  NaN
# 258                             NaN               NaN                  NaN
# 273                             NaN               NaN                  NaN
# 286                             NaN               NaN                  NaN
# 289                             NaN               NaN                  NaN
# ...                             ...               ...                  ...
# 678429                          NaN               NaN                  NaN
# 678434                          NaN               NaN                  NaN
# 678437                          NaN               NaN                  NaN
# 678439                          NaN               NaN                  NaN
# 678455                          NaN               NaN                  NaN
# 678467                          NaN               NaN                  NaN
# 678472                          NaN               NaN                  NaN
# 678476                          NaN               NaN                  NaN
# 678481                          NaN               NaN                  NaN
# 678484                          NaN               NaN                  NaN
# 678496                          NaN               NaN                  NaN
# 678498                          NaN               NaN                  NaN
# 678503                          NaN               NaN                  NaN
# 678506                          NaN               NaN                  NaN
# 678518                          NaN               NaN                  NaN
# 678532                          NaN               NaN                  NaN
# 678540                          NaN               NaN                  NaN
# 678547                          NaN               NaN                  NaN
# 678553                          NaN               NaN                  NaN
# 678555                          NaN               NaN                  NaN
# 678567                          NaN               NaN                  NaN
# 678577                          NaN               NaN                  NaN
# 678578                          NaN               NaN                  NaN
# 678586                          NaN               NaN                  NaN
# 678610                          NaN               NaN                  NaN
# 678615                          NaN               NaN                  NaN
# 678617                          NaN               NaN                  NaN
# 678620                          NaN               NaN                  NaN
# 678622                          NaN               NaN                  NaN
# 678636                          NaN               NaN                  NaN
#
#        Apartments  ... Building Square Feet Repair Condition  Use  \
# 8             NaN  ...                  NaN              NaN  NaN
# 33            NaN  ...                  NaN              NaN  NaN
# 42            NaN  ...                  NaN              NaN  NaN
# 43            NaN  ...                  NaN              NaN  NaN
# 52            NaN  ...                  NaN              NaN  NaN
# 68            NaN  ...                  NaN              NaN  NaN
# 77            NaN  ...                  NaN              NaN  NaN
# 97            NaN  ...                  NaN              NaN  NaN
# 103           NaN  ...                  NaN              NaN  NaN
# 106           NaN  ...                  NaN              NaN  NaN
# 109           NaN  ...                  NaN              NaN  NaN
# 118           NaN  ...                  NaN              NaN  NaN
# 139           NaN  ...                  NaN              NaN  NaN
# 144           NaN  ...                  NaN              NaN  NaN
# 158           NaN  ...                  NaN              NaN  NaN
# 162           NaN  ...                  NaN              NaN  NaN
# 165           NaN  ...                  NaN              NaN  NaN
# 176           NaN  ...                  NaN              NaN  NaN
# 177           NaN  ...                  NaN              NaN  NaN
# 184           NaN  ...                  NaN              NaN  NaN
# 194           NaN  ...                  NaN              NaN  NaN
# 202           NaN  ...                  NaN              NaN  NaN
# 222           NaN  ...                  NaN              NaN  NaN
# 229           NaN  ...                  NaN              NaN  NaN
# 239           NaN  ...                  NaN              NaN  NaN
# 243           NaN  ...                  NaN              NaN  NaN
# 258           NaN  ...                  NaN              NaN  NaN
# 273           NaN  ...                  NaN              NaN  NaN
# 286           NaN  ...                  NaN              NaN  NaN
# 289           NaN  ...                  NaN              NaN  NaN
# ...           ...  ...                  ...              ...  ...
# 678429        NaN  ...                  NaN              NaN  NaN
# 678434        NaN  ...                  NaN              NaN  NaN
# 678437        NaN  ...                  NaN              NaN  NaN
# 678439        NaN  ...                  NaN              NaN  NaN
# 678455        NaN  ...                  NaN              NaN  NaN
# 678467        NaN  ...                  NaN              NaN  NaN
# 678472        NaN  ...                  NaN              NaN  NaN
# 678476        NaN  ...                  NaN              NaN  NaN
# 678481        NaN  ...                  NaN              NaN  NaN
# 678484        NaN  ...                  NaN              NaN  NaN
# 678496        NaN  ...                  NaN              NaN  NaN
# 678498        NaN  ...                  NaN              NaN  NaN
# 678503        NaN  ...                  NaN              NaN  NaN
# 678506        NaN  ...                  NaN              NaN  NaN
# 678518        NaN  ...                  NaN              NaN  NaN
# 678532        NaN  ...                  NaN              NaN  NaN
# 678540        NaN  ...                  NaN              NaN  NaN
# 678547        NaN  ...                  NaN              NaN  NaN
# 678553        NaN  ...                  NaN              NaN  NaN
# 678555        NaN  ...                  NaN              NaN  NaN
# 678567        NaN  ...                  NaN              NaN  NaN
# 678577        NaN  ...                  NaN              NaN  NaN
# 678578        NaN  ...                  NaN              NaN  NaN
# 678586        NaN  ...                  NaN              NaN  NaN
# 678610        NaN  ...                  NaN              NaN  NaN
# 678615        NaN  ...                  NaN              NaN  NaN
# 678617        NaN  ...                  NaN              NaN  NaN
# 678620        NaN  ...                  NaN              NaN  NaN
# 678622        NaN  ...                  NaN              NaN  NaN
# 678636        NaN  ...                  NaN              NaN  NaN
#
#         Type of Residence Attic Finish Renovation Porch Property Zip Code  \
# 8                     NaN          NaN        NaN   NaN               NaN
# 33                    NaN          NaN        NaN   NaN               NaN
# 42                    NaN          NaN        NaN   NaN               NaN
# 43                    NaN          NaN        NaN   NaN               NaN
# 52                    NaN          NaN        NaN   NaN               NaN
# 68                    NaN          NaN        NaN   NaN               NaN
# 77                    NaN          NaN        NaN   NaN               NaN
# 97                    NaN          NaN        NaN   NaN               NaN
# 103                   NaN          NaN        NaN   NaN               NaN
# 106                   NaN          NaN        NaN   NaN               NaN
# 109                   NaN          NaN        NaN   NaN               NaN
# 118                   NaN          NaN        NaN   NaN               NaN
# 139                   NaN          NaN        NaN   NaN               NaN
# 144                   NaN          NaN        NaN   NaN               NaN
# 158                   NaN          NaN        NaN   NaN               NaN
# 162                   NaN          NaN        NaN   NaN               NaN
# 165                   NaN          NaN        NaN   NaN               NaN
# 176                   NaN          NaN        NaN   NaN               NaN
# 177                   NaN          NaN        NaN   NaN               NaN
# 184                   NaN          NaN        NaN   NaN               NaN
# 194                   NaN          NaN        NaN   NaN               NaN
# 202                   NaN          NaN        NaN   NaN               NaN
# 222                   NaN          NaN        NaN   NaN               NaN
# 229                   NaN          NaN        NaN   NaN               NaN
# 239                   NaN          NaN        NaN   NaN               NaN
# 243                   NaN          NaN        NaN   NaN               NaN
# 258                   NaN          NaN        NaN   NaN               NaN
# 273                   NaN          NaN        NaN   NaN               NaN
# 286                   NaN          NaN        NaN   NaN               NaN
# 289                   NaN          NaN        NaN   NaN               NaN
# ...                   ...          ...        ...   ...               ...
# 678429                NaN          NaN        NaN   NaN               NaN
# 678434                NaN          NaN        NaN   NaN               NaN
# 678437                NaN          NaN        NaN   NaN               NaN
# 678439                NaN          NaN        NaN   NaN               NaN
# 678455                NaN          NaN        NaN   NaN               NaN
# 678467                NaN          NaN        NaN   NaN               NaN
# 678472                NaN          NaN        NaN   NaN               NaN
# 678476                NaN          NaN        NaN   NaN               NaN
# 678481                NaN          NaN        NaN   NaN               NaN
# 678484                NaN          NaN        NaN   NaN               NaN
# 678496                NaN          NaN        NaN   NaN               NaN
# 678498                NaN          NaN        NaN   NaN               NaN
# 678503                NaN          NaN        NaN   NaN               NaN
# 678506                NaN          NaN        NaN   NaN               NaN
# 678518                NaN          NaN        NaN   NaN               NaN
# 678532                NaN          NaN        NaN   NaN               NaN
# 678540                NaN          NaN        NaN   NaN               NaN
# 678547                NaN          NaN        NaN   NaN               NaN
# 678553                NaN          NaN        NaN   NaN               NaN
# 678555                NaN          NaN        NaN   NaN               NaN
# 678567                NaN          NaN        NaN   NaN               NaN
# 678577                NaN          NaN        NaN   NaN               NaN
# 678578                NaN          NaN        NaN   NaN               NaN
# 678586                NaN          NaN        NaN   NaN               NaN
# 678610                NaN          NaN        NaN   NaN               NaN
# 678615                NaN          NaN        NaN   NaN               NaN
# 678617                NaN          NaN        NaN   NaN               NaN
# 678620                NaN          NaN        NaN   NaN               NaN
# 678622                NaN          NaN        NaN   NaN               NaN
# 678636                NaN          NaN        NaN   NaN               NaN
#
#         Municipality FIPS Code Municipality Name
# 8                      14000.0           Chicago
# 33                     14000.0           Chicago
# 42                     14000.0           Chicago
# 43                     14000.0           Chicago
# 52                     14000.0           Chicago
# 68                     14000.0           Chicago
# 77                     14000.0           Chicago
# 97                     14000.0           Chicago
# 103                    14000.0           Chicago
# 106                    14000.0           Chicago
# 109                    14000.0           Chicago
# 118                    14000.0           Chicago
# 139                    14000.0           Chicago
# 144                    14000.0           Chicago
# 158                    14000.0           Chicago
# 162                    14000.0           Chicago
# 165                    14000.0           Chicago
# 176                    14000.0           Chicago
# 177                    14000.0           Chicago
# 184                    14000.0           Chicago
# 194                    14000.0           Chicago
# 202                    14000.0           Chicago
# 222                    14000.0           Chicago
# 229                    14000.0           Chicago
# 239                    14000.0           Chicago
# 243                    14000.0           Chicago
# 258                    14000.0           Chicago
# 273                    14000.0           Chicago
# 286                    14000.0           Chicago
# 289                    14000.0           Chicago
# ...                        ...               ...
# 678429                 14000.0           Chicago
# 678434                 14000.0           Chicago
# 678437                 14000.0           Chicago
# 678439                 14000.0           Chicago
# 678455                 14000.0           Chicago
# 678467                 14000.0           Chicago
# 678472                 14000.0           Chicago
# 678476                 14000.0           Chicago
# 678481                 14000.0           Chicago
# 678484                 14000.0           Chicago
# 678496                 14000.0           Chicago
# 678498                 14000.0           Chicago
# 678503                 14000.0           Chicago
# 678506                 14000.0           Chicago
# 678518                 14000.0           Chicago
# 678532                 14000.0           Chicago
# 678540                 14000.0           Chicago
# 678547                 14000.0           Chicago
# 678553                 14000.0           Chicago
# 678555                 14000.0           Chicago
# 678567                 14000.0           Chicago
# 678577                 14000.0           Chicago
# 678578                 14000.0           Chicago
# 678586                 14000.0           Chicago
# 678610                 14000.0           Chicago
# 678615                 14000.0           Chicago
# 678617                 14000.0           Chicago
# 678620                 14000.0           Chicago
# 678622                 14000.0           Chicago
# 678636                 14000.0           Chicago
#
# [78156 rows x 38 columns]

# %% [markdown]
# # Data visualization

# %%
for feature in feautres_na:
    na_data = data.copy()
    na_data[feature] = np.where(na_data[feature].isnull(),1,0) # replacing missing value with 1 and rest with 0
    na_data.groupby(feature)['Sale Price'].mean().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# I observe that there is relationship between features with missing values and dependent variable (Sales Price).So I need to replace these missing values with meaningful data.
# Next, I check which features are having numerical data.

# %%
numerical_features = [features for features in data.columns if data[features].dtypes != 'O']
numerical_features
# Out:
# ['Property Class',
#  'Township Code',
#  'Neighborhood Code',
#  'Township Neighborhood Only',
#  'Proportion Assessed',
#  'Multi Code Indicator',
#  'Multi Code',
#  'Number of Active 288s (HIEs)',
#  'Number of Ended 288s (HIEs)',
#  'Sale Price',
#  'Sale Document Number',
#  'Land Square Feet',
#  'Age',
#  'Rooms',
#  'Bedrooms',
#  'Fireplaces',
#  'Full Baths',
#  'Half Baths',
#  'Building Square Feet',
#  'Tract GEOID',
#  'Municipality FIPS Code',
#  "O'Hare Noise Indicator",
#  'FEMA Floodplain',
#  'Flood Risk Factor',
#  'Flood Risk Direction',
#  'Road Proximity < 100 Feet',
#  'Road Proximity 101 - 300 Feet',
#  'Longitude',
#  'Latitude',
#  'Tax Rate',
#  'Tract Median Income']

# %%
data[numerical_features].head()
# Out:
#     Property Class  Township Code  Neighborhood Code  \
# 8              299             71              71082
# 33             299             73              73031
# 42             299             72              72380
# 43             299             77              77131
# 52             299             73              73084
#
#     Township Neighborhood Only  Proportion Assessed  Multi Code Indicator  \
# 8                           82             0.052600                     0
# 33                          31             0.087400                     0
# 42                         380             0.055400                     0
# 43                         131             0.005058                     0
# 52                          84             0.033800                     0
#
#     Multi Code  Number of Active 288s (HIEs)  Number of Ended 288s (HIEs)  \
# 8          2.0                           NaN                          NaN
# 33         2.0                           NaN                          NaN
# 42         2.0                           NaN                          NaN
# 43         2.0                           NaN                          NaN
# 52         2.0                           NaN                          NaN
#
#     Sale Price  ...  O'Hare Noise Indicator  FEMA Floodplain  \
# 8     225000.0  ...                       0                0
# 33    295000.0  ...                       0                0
# 42    100500.0  ...                       0                0
# 43    261000.0  ...                       0                0
# 52    207000.0  ...                       0                0
#
#     Flood Risk Factor  Flood Risk Direction  Road Proximity < 100 Feet  \
# 8                   4                     1                          0
# 33                  6                     1                          0
# 42                  1                     0                          0
# 43                  6                     0                          0
# 52                  1                     0                          0
#
#     Road Proximity 101 - 300 Feet  Longitude   Latitude  Tax Rate  \
# 8                               0 -87.705654  41.946889     6.913
# 33                              0 -87.665250  41.981877     6.890
# 42                              0 -87.775142  41.774606     6.890
# 43                              1 -87.641703  41.874852     6.890
# 52                              0 -87.652401  41.951394     6.890
#
#     Tract Median Income
# 8                 79671
# 33                90288
# 42                44085
# 43               116377
# 52                72778
#
# [5 rows x 31 columns]

# %%
for feature in numerical_features:
    num_data = data.copy()
    plt.scatter(num_data[feature],data['Sale Price'])
    plt.title(feature)
    plt.show()

# %%
discrete_features = [feature for feature in numerical_features if len(data[feature].unique())<15 and feature]
print(len(discrete_features))
discrete_features
# Out:
# 15
# ['Township Code',
#  'Multi Code Indicator',
#  'Multi Code',
#  'Number of Active 288s (HIEs)',
#  'Number of Ended 288s (HIEs)',
#  'Fireplaces',
#  'Full Baths',
#  'Half Baths',
#  'Municipality FIPS Code',
#  "O'Hare Noise Indicator",
#  'FEMA Floodplain',
#  'Flood Risk Factor',
#  'Flood Risk Direction',
#  'Road Proximity < 100 Feet',
#  'Road Proximity 101 - 300 Feet']

# %%
data[discrete_features].head()
# Out:
#     Township Code  Multi Code Indicator  Multi Code  \
# 8              71                     0         2.0
# 33             73                     0         2.0
# 42             72                     0         2.0
# 43             77                     0         2.0
# 52             73                     0         2.0
#
#     Number of Active 288s (HIEs)  Number of Ended 288s (HIEs)  Fireplaces  \
# 8                            NaN                          NaN         NaN
# 33                           NaN                          NaN         NaN
# 42                           NaN                          NaN         NaN
# 43                           NaN                          NaN         NaN
# 52                           NaN                          NaN         NaN
#
#     Full Baths  Half Baths  Municipality FIPS Code  O'Hare Noise Indicator  \
# 8          NaN         NaN                 14000.0                       0
# 33         NaN         NaN                 14000.0                       0
# 42         NaN         NaN                 14000.0                       0
# 43         NaN         NaN                 14000.0                       0
# 52         NaN         NaN                 14000.0                       0
#
#     FEMA Floodplain  Flood Risk Factor  Flood Risk Direction  \
# 8                 0                  4                     1
# 33                0                  6                     1
# 42                0                  1                     0
# 43                0                  6                     0
# 52                0                  1                     0
#
#     Road Proximity < 100 Feet  Road Proximity 101 - 300 Feet
# 8                           0                              0
# 33                          0                              0
# 42                          0                              0
# 43                          0                              1
# 52                          0                              0

# %%
for feature in discrete_features:
    dis_data = df.copy()
    dis_data.groupby(feature)['Sale Price'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Sale Price')
    plt.title(feature)
    plt.show()

# %%
continous_features = [feature for feature in numerical_features if feature not in discrete_features]
print(len(continous_features))
continous_features
# Out:
# 16
# ['Property Class',
#  'Neighborhood Code',
#  'Township Neighborhood Only',
#  'Proportion Assessed',
#  'Sale Price',
#  'Sale Document Number',
#  'Land Square Feet',
#  'Age',
#  'Rooms',
#  'Bedrooms',
#  'Building Square Feet',
#  'Tract GEOID',
#  'Longitude',
#  'Latitude',
#  'Tax Rate',
#  'Tract Median Income']

# %%
#Using histograms for continous numerical variable to study patterns
for feature in continous_features:
    cont_data = df.copy()
    cont_data[feature].hist(bins = 25)
    plt.title(feature)
    
    plt.show()

# %% [markdown]
# Observing that some of the distributions are skewed
#
# I will normalise the skewed ones with lograthmic transformation

# %%
for feature in continous_features:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data['Sale Price'] = np.log(data['Sale Price'])
        plt.scatter(data[feature],data['Sale Price'])
        plt.xlabel(feature)
        plt.ylabel('Sales Price')
        plt.title(feature)
        plt.show()
# Out:
# C:\Users\Yerlan\anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
for feature in continous_features:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data['Sale Price'] = np.log(data['Sale Price'])
        data[feature].hist(bins = 25)
        plt.xlabel(feature)
        plt.ylabel('Sales Price')
        plt.title(feature)
        plt.show()

# %%
#Observing categorical features 
categorical_features =[feature for feature in data.columns if data[feature].dtypes == 'O']
categorical_features
# Out:
# ['Property Index Number',
#  'Assessment Triad',
#  'Property Address',
#  'Property Apartment Num.',
#  'Property City',
#  'Township Name',
#  'Modeling Group',
#  'Key PIN',
#  'Sale Date',
#  'Large Home Indicator',
#  'Apartments',
#  'Wall Material',
#  'Roof Material',
#  'Basement',
#  'Basement Finish',
#  'Central Heating',
#  'Central Air Conditioning',
#  'Attic Type',
#  'Design Plan',
#  'Cathedral Ceiling',
#  'Garage 1 Size',
#  'Garage 1 Material',
#  'Garage 1 Attached',
#  'Garage 1 Area',
#  'Repair Condition',
#  'Use',
#  'Type of Residence',
#  'Attic Finish',
#  'Renovation',
#  'Porch',
#  'Property Zip Code',
#  'Municipality Name',
#  'Elementary/Middle School District',
#  'High School District',
#  'geoposition']

# %%
for feature in categorical_features:
    print("Distinct categories for {}  are {}".format(feature,len(data[feature].unique())))
# Out:
# Distinct categories for Property Index Number  are 78151
# Distinct categories for Assessment Triad  are 1
# Distinct categories for Property Address  are 45084
# Distinct categories for Property Apartment Num.  are 225
# Distinct categories for Property City  are 2
# Distinct categories for Township Name  are 8
# Distinct categories for Modeling Group  are 3
# Distinct categories for Key PIN  are 20612
# Distinct categories for Sale Date  are 711
# Distinct categories for Large Home Indicator  are 3
# Distinct categories for Apartments  are 7
# Distinct categories for Wall Material  are 5
# Distinct categories for Roof Material  are 7
# Distinct categories for Basement  are 5
# Distinct categories for Basement Finish  are 4
# Distinct categories for Central Heating  are 5
# Distinct categories for Central Air Conditioning  are 3
# Distinct categories for Attic Type  are 4
# Distinct categories for Design Plan  are 3
# Distinct categories for Cathedral Ceiling  are 3
# Distinct categories for Garage 1 Size  are 9
# Distinct categories for Garage 1 Material  are 5
# Distinct categories for Garage 1 Attached  are 3
# Distinct categories for Garage 1 Area  are 3
# Distinct categories for Repair Condition  are 4
# Distinct categories for Use  are 3
# Distinct categories for Type of Residence  are 10
# Distinct categories for Attic Finish  are 4
# Distinct categories for Renovation  are 3
# Distinct categories for Porch  are 4
# Distinct categories for Property Zip Code  are 26714
# Distinct categories for Municipality Name  are 2
# Distinct categories for Elementary/Middle School District  are 355
# Distinct categories for High School District  are 47
# Distinct categories for geoposition  are 54613

# %%
# Checking the null values
data.isnull().sum()
# Out:
# Property Index Number                    0
# Assessment Triad                         0
# Property Class                           0
# Property Address                     32606
# Property Apartment Num.              72172
# Property City                        32606
# Township Name                            0
# Township Code                            0
# Neighborhood Code                        0
# Township Neighborhood Only               0
# Modeling Group                           0
# Proportion Assessed                      0
# Key PIN                              45500
# Multi Code Indicator                     0
# Multi Code                              22
# Number of Active 288s (HIEs)         32579
# Number of Ended 288s (HIEs)          32579
# Sale Date                                0
# Sale Price                               0
# Sale Document Number                     0
# Land Square Feet                     32579
# Large Home Indicator                 32579
# Age                                      0
# Apartments                           65531
# Wall Material                        32585
# Roof Material                        32585
# Rooms                                32579
# Bedrooms                             32579
# Basement                             32585
# Basement Finish                      32585
#                                      ...
# Design Plan                          44928
# Cathedral Ceiling                    54228
# Garage 1 Size                        32584
# Garage 1 Material                    43703
# Garage 1 Attached                    43704
# Garage 1 Area                        43704
# Building Square Feet                 32579
# Repair Condition                     32585
# Use                                  32584
# Type of Residence                    32585
# Attic Finish                         61650
# Renovation                           77843
# Porch                                66324
# Property Zip Code                    32606
# Tract GEOID                              0
# Municipality FIPS Code                  51
# Municipality Name                       51
# O'Hare Noise Indicator                   0
# FEMA Floodplain                          0
# Flood Risk Factor                        0
# Flood Risk Direction                     0
# Road Proximity < 100 Feet                0
# Road Proximity 101 - 300 Feet            0
# Elementary/Middle School District        0
# High School District                     0
# Longitude                                0
# Latitude                                 0
# geoposition                              0
# Tax Rate                                 0
# Tract Median Income                      0
# Length: 66, dtype: int64

# %%
# heatmap for visualizing the null vaues
sns.heatmap(data.isnull(),yticklabels = False,cbar = False)
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78156 entries, 8 to 678636
# Data columns (total 66 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Property Index Number              78156 non-null  object
#  1   Assessment Triad                   78156 non-null  object
#  2   Property Class                     78156 non-null  int64
#  3   Property Address                   45550 non-null  object
#  4   Property Apartment Num.            5984 non-null   object
#  5   Property City                      45550 non-null  object
#  6   Township Name                      78156 non-null  object
#  7   Township Code                      78156 non-null  int64
#  8   Neighborhood Code                  78156 non-null  int64
#  9   Township Neighborhood Only         78156 non-null  int64
#  10  Modeling Group                     78156 non-null  object
#  11  Proportion Assessed                78156 non-null  float64
#  12  Key PIN                            32656 non-null  object
#  13  Multi Code Indicator               78156 non-null  int64
#  14  Multi Code                         78134 non-null  float64
#  15  Number of Active 288s (HIEs)       45577 non-null  float64
#  16  Number of Ended 288s (HIEs)        45577 non-null  float64
#  17  Sale Date                          78156 non-null  object
#  18  Sale Price                         78156 non-null  float64
#  19  Sale Document Number               78156 non-null  float64
#  20  Land Square Feet                   45577 non-null  float64
#  21  Large Home Indicator               45577 non-null  object
#  22  Age                                78156 non-null  int64
#  23  Apartments                         12625 non-null  object
#  24  Wall Material                      45571 non-null  object
#  25  Roof Material                      45571 non-null  object
#  26  Rooms                              45577 non-null  float64
#  27  Bedrooms                           45577 non-null  float64
#  28  Basement                           45571 non-null  object
#  29  Basement Finish                    45571 non-null  object
#  30  Central Heating                    45571 non-null  object
#  31  Central Air Conditioning           45571 non-null  object
#  32  Fireplaces                         45572 non-null  float64
#  33  Attic Type                         45571 non-null  object
#  34  Full Baths                         45577 non-null  float64
#  35  Half Baths                         45577 non-null  float64
#  36  Design Plan                        33228 non-null  object
#  37  Cathedral Ceiling                  23928 non-null  object
#  38  Garage 1 Size                      45572 non-null  object
#  39  Garage 1 Material                  34453 non-null  object
#  40  Garage 1 Attached                  34452 non-null  object
#  41  Garage 1 Area                      34452 non-null  object
#  42  Building Square Feet               45577 non-null  float64
#  43  Repair Condition                   45571 non-null  object
#  44  Use                                45572 non-null  object
#  45  Type of Residence                  45571 non-null  object
#  46  Attic Finish                       16506 non-null  object
#  47  Renovation                         313 non-null    object
#  48  Porch                              11832 non-null  object
#  49  Property Zip Code                  45550 non-null  object
#  50  Tract GEOID                        78156 non-null  int64
#  51  Municipality FIPS Code             78105 non-null  float64
#  52  Municipality Name                  78105 non-null  object
#  53  O'Hare Noise Indicator             78156 non-null  int64
#  54  FEMA Floodplain                    78156 non-null  int64
#  55  Flood Risk Factor                  78156 non-null  int64
#  56  Flood Risk Direction               78156 non-null  int64
#  57  Road Proximity < 100 Feet          78156 non-null  int64
#  58  Road Proximity 101 - 300 Feet      78156 non-null  int64
#  59  Elementary/Middle School District  78156 non-null  object
#  60  High School District               78156 non-null  object
#  61  Longitude                          78156 non-null  float64
#  62  Latitude                           78156 non-null  float64
#  63  geoposition                        78156 non-null  object
#  64  Tax Rate                           78156 non-null  float64
#  65  Tract Median Income                78156 non-null  float64
# dtypes: float64(18), int64(13), object(35)
# memory usage: 40.0+ MB

# %% [markdown]
# # Data cleaning

# %%
for feature in categorical_features:
    data[feature] = data[feature].fillna(data[feature].mode()[0])

# %%
for feature in discrete_features:
    data[feature] = data[feature].fillna(data[feature].mode()[0])

# %%
for feature in continous_features:
    data[feature] = data[feature].fillna(data[feature].mean())

# %%
for feature in more_than_45_percent_misssing_value_features:
    data.drop([feature],axis = 1, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78156 entries, 8 to 678636
# Data columns (total 55 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Property Index Number              78156 non-null  object
#  1   Assessment Triad                   78156 non-null  object
#  2   Property Class                     78156 non-null  int64
#  3   Property Address                   78156 non-null  object
#  4   Property City                      78156 non-null  object
#  5   Township Name                      78156 non-null  object
#  6   Township Code                      78156 non-null  int64
#  7   Neighborhood Code                  78156 non-null  int64
#  8   Township Neighborhood Only         78156 non-null  int64
#  9   Modeling Group                     78156 non-null  object
#  10  Proportion Assessed                78156 non-null  float64
#  11  Multi Code Indicator               78156 non-null  int64
#  12  Multi Code                         78156 non-null  float64
#  13  Number of Active 288s (HIEs)       78156 non-null  float64
#  14  Number of Ended 288s (HIEs)        78156 non-null  float64
#  15  Sale Date                          78156 non-null  object
#  16  Sale Price                         78156 non-null  float64
#  17  Sale Document Number               78156 non-null  float64
#  18  Land Square Feet                   78156 non-null  float64
#  19  Large Home Indicator               78156 non-null  bool
#  20  Age                                78156 non-null  int64
#  21  Wall Material                      78156 non-null  object
#  22  Roof Material                      78156 non-null  object
#  23  Rooms                              78156 non-null  float64
#  24  Bedrooms                           78156 non-null  float64
#  25  Basement                           78156 non-null  object
#  26  Basement Finish                    78156 non-null  object
#  27  Central Heating                    78156 non-null  object
#  28  Central Air Conditioning           78156 non-null  object
#  29  Fireplaces                         78156 non-null  float64
#  30  Attic Type                         78156 non-null  object
#  31  Full Baths                         78156 non-null  float64
#  32  Half Baths                         78156 non-null  float64
#  33  Garage 1 Size                      78156 non-null  object
#  34  Building Square Feet               78156 non-null  float64
#  35  Repair Condition                   78156 non-null  object
#  36  Use                                78156 non-null  object
#  37  Type of Residence                  78156 non-null  object
#  38  Property Zip Code                  78156 non-null  object
#  39  Tract GEOID                        78156 non-null  int64
#  40  Municipality FIPS Code             78156 non-null  float64
#  41  Municipality Name                  78156 non-null  object
#  42  O'Hare Noise Indicator             78156 non-null  int64
#  43  FEMA Floodplain                    78156 non-null  int64
#  44  Flood Risk Factor                  78156 non-null  int64
#  45  Flood Risk Direction               78156 non-null  int64
#  46  Road Proximity < 100 Feet          78156 non-null  int64
#  47  Road Proximity 101 - 300 Feet      78156 non-null  int64
#  48  Elementary/Middle School District  78156 non-null  object
#  49  High School District               78156 non-null  object
#  50  Longitude                          78156 non-null  float64
#  51  Latitude                           78156 non-null  float64
#  52  geoposition                        78156 non-null  object
#  53  Tax Rate                           78156 non-null  float64
#  54  Tract Median Income                78156 non-null  float64
# dtypes: bool(1), float64(18), int64(13), object(23)
# memory usage: 32.9+ MB

# %%
data.drop(['Sale Date','Property Zip Code','geoposition'],axis = 1, inplace = True)

# %%
data.rename(columns = {'Road Proximity < 100 Feet':'Road Proximity under 100 Feet'}, inplace = True)

# %%
#Storing data
with open('data1.pkl', 'wb') as file:
    dill.dump(data, file)

# %%
with open('data1.pkl', 'rb') as file:
    data1 = dill.load(file)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78156 entries, 8 to 678636
# Data columns (total 50 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Assessment Triad                   78156 non-null  object
#  1   Property Class                     78156 non-null  int64
#  2   Property City                      78156 non-null  object
#  3   Township Name                      78156 non-null  object
#  4   Township Code                      78156 non-null  int64
#  5   Neighborhood Code                  78156 non-null  int64
#  6   Township Neighborhood Only         78156 non-null  int64
#  7   Modeling Group                     78156 non-null  object
#  8   Proportion Assessed                78156 non-null  float64
#  9   Multi Code Indicator               78156 non-null  int64
#  10  Multi Code                         78156 non-null  float64
#  11  Number of Active 288s (HIEs)       78156 non-null  float64
#  12  Number of Ended 288s (HIEs)        78156 non-null  float64
#  13  Sale Price                         78156 non-null  float64
#  14  Sale Document Number               78156 non-null  float64
#  15  Land Square Feet                   78156 non-null  float64
#  16  Large Home Indicator               78156 non-null  bool
#  17  Age                                78156 non-null  int64
#  18  Wall Material                      78156 non-null  object
#  19  Roof Material                      78156 non-null  object
#  20  Rooms                              78156 non-null  float64
#  21  Bedrooms                           78156 non-null  float64
#  22  Basement                           78156 non-null  object
#  23  Basement Finish                    78156 non-null  object
#  24  Central Heating                    78156 non-null  object
#  25  Central Air Conditioning           78156 non-null  object
#  26  Fireplaces                         78156 non-null  float64
#  27  Attic Type                         78156 non-null  object
#  28  Full Baths                         78156 non-null  float64
#  29  Half Baths                         78156 non-null  float64
#  30  Garage 1 Size                      78156 non-null  object
#  31  Building Square Feet               78156 non-null  float64
#  32  Repair Condition                   78156 non-null  object
#  33  Use                                78156 non-null  object
#  34  Type of Residence                  78156 non-null  object
#  35  Tract GEOID                        78156 non-null  int64
#  36  Municipality FIPS Code             78156 non-null  float64
#  37  Municipality Name                  78156 non-null  object
#  38  O'Hare Noise Indicator             78156 non-null  int64
#  39  FEMA Floodplain                    78156 non-null  int64
#  40  Flood Risk Factor                  78156 non-null  int64
#  41  Flood Risk Direction               78156 non-null  int64
#  42  Road Proximity under 100 Feet      78156 non-null  int64
#  43  Road Proximity 101 - 300 Feet      78156 non-null  int64
#  44  Elementary/Middle School District  78156 non-null  object
#  45  High School District               78156 non-null  object
#  46  Longitude                          78156 non-null  float64
#  47  Latitude                           78156 non-null  float64
#  48  Tax Rate                           78156 non-null  float64
#  49  Tract Median Income                78156 non-null  float64
# dtypes: bool(1), float64(18), int64(13), object(18)
# memory usage: 29.9+ MB

# %%
# heatmap for visualizing the null vaues
sns.heatmap(data1.isnull(),yticklabels = False,cbar = False)
# Out:
# <AxesSubplot:>

# %%
data1.shape
# Out:
# (78156, 32)

# %% [markdown]
# Data Transformation by One Hot Encoding of categorical variables

# %%
columns =[feature for feature in data.columns if data1[feature].dtypes == 'O']
len(columns)
# Out:
# 18

# %%
# function to convert categorical variables to one hot encoding
def category_onehot_multcols(multcolumns):
    df_final=final_df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(final_df[fields],drop_first=True)
        
        final_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([final_df,df_final],axis=1)
        
    return df_final

# %%
final_df=data1

# %%
final_df.shape
# Out:
# (78156, 50)

# %%
final_df=category_onehot_multcols(columns)
# Out:
# Assessment Triad
# Property City
# Township Name
# Modeling Group
# Wall Material
# Roof Material
# Basement
# Basement Finish
# Central Heating
# Central Air Conditioning
# Attic Type
# Garage 1 Size
# Repair Condition
# Use
# Type of Residence
# Municipality Name
# Elementary/Middle School District
# High School District

# %%
final_df.shape
# Out:
# (78156, 478)

# %%
# removing duplicated columns
final_df =final_df.loc[:,~final_df.columns.duplicated()]

# %%
final_df.shape
# Out:
# (78156, 476)

# %%
#Storing data
with open('final_df.pkl', 'wb') as file:
    dill.dump(final_df, file)

# %%
with open('final_df.pkl', 'rb') as file:
    final_df = dill.load(file)

# %%
X = final_df.drop('Sale Price', axis=1)
y = final_df['Sale Price']

# %% [markdown]
# # Base model implementation - Regression

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (62524, 475)

# %%
X_train.head()
# Out:
#         Property Class  Township Code  Neighborhood Code  \
# 376855             202             72              72423
# 585953             299             77              77051
# 581116             299             71              71082
# 219771             211             76              76030
# 264609             203             72              72380
#
#         Township Neighborhood Only  Proportion Assessed  Multi Code Indicator  \
# 376855                         423               1.0000                     0
# 585953                          51               0.3446                     0
# 581116                          82               0.0529                     0
# 219771                          30               1.0000                     0
# 264609                         380               1.0000                     0
#
#         Multi Code  Number of Active 288s (HIEs)  Number of Ended 288s (HIEs)  \
# 376855         2.0                           0.0                          0.0
# 585953         2.0                           0.0                          0.0
# 581116         2.0                           0.0                          0.0
# 219771         2.0                           0.0                          1.0
# 264609         2.0                           0.0                          0.0
#
#         Sale Document Number  ...  ROOSEVELT HS  SCHURZ HS  SENN HS  \
# 376855          2.025307e+09  ...             0          0        0
# 585953          1.823619e+09  ...             0          0        0
# 581116          1.818608e+09  ...             1          0        0
# 219771          1.832057e+09  ...             0          0        0
# 264609          1.822712e+09  ...             0          0        0
#
#         SOLORIO HS  STEINMETZ COLLEGE PREP HS  SULLIVAN HS  TAFT HS  \
# 376855           0                          0            0        0
# 585953           0                          0            0        0
# 581116           0                          0            0        0
# 219771           0                          0            0        0
# 264609           0                          0            0        0
#
#         TILDEN HS  WASHINGTON HS  WELLS HS
# 376855          0              0         0
# 585953          0              0         1
# 581116          0              0         0
# 219771          1              0         0
# 264609          0              0         0
#
# [5 rows x 475 columns]

# %%
print(X_train.columns)
# Out:
# Index(['Property Class', 'Township Code', 'Neighborhood Code',
#        'Township Neighborhood Only', 'Proportion Assessed',
#        'Multi Code Indicator', 'Multi Code', 'Number of Active 288s (HIEs)',
#        'Number of Ended 288s (HIEs)', 'Sale Document Number',
#        ...
#        'ROOSEVELT HS', 'SCHURZ HS', 'SENN HS', 'SOLORIO HS',
#        'STEINMETZ COLLEGE PREP HS', 'SULLIVAN HS', 'TAFT HS', 'TILDEN HS',
#        'WASHINGTON HS', 'WELLS HS'],
#       dtype='object', length=475)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()  
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
# RMSE Computation
from sklearn.metrics import mean_squared_error as MSE
rmse = np.sqrt(MSE(y_test, y_pred))
print("RMSE : % f" %(rmse))
# Out:
# RMSE :  0.456611

# %%
from sklearn import metrics
print("R^2:", metrics.r2_score(y_test, y_pred))
# Out:
# R^2: 0.6846838846201059

# %% [markdown]
# # XGBoost model implemenation

# %%
conda install -c conda-forge py-xgboost
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Yerlan\anaconda3
#
#   added / updated specs:
#     - py-xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _py-xgboost-mutex-2.0      |            cpu_0          11 KB  conda-forge
#     conda-4.13.0               |   py39hcbf5309_1         1.0 MB  conda-forge
#     libxgboost-1.5.1           |   cpu_h110a20b_2         2.3 MB  conda-forge
#     py-xgboost-1.5.1           |cpu_py39ha538f94_2         151 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   _py-xgboost-mutex  conda-forge/win-64::_py-xgboost-mutex-2.0-cpu_0
#   libxgboost         conda-forge/win-64::libxgboost-1.5.1-cpu_h110a20b_2
#   py-xgboost         conda-forge/win-64::py-xgboost-1.5.1-cpu_py39ha538f94_2
#   python_abi         conda-forge/win-64::python_abi-3.9-2_cp39
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-4.12.0-py39haa95532_0 --> conda-forge::conda-4.13.0-py39hcbf5309_1
#
#
#
# Downloading and Extracting Packages
#
# py-xgboost-1.5.1     | 151 KB    |            |   0%
# py-xgboost-1.5.1     | 151 KB    | #          |  11%
# py-xgboost-1.5.1     | 151 KB    | ########## | 100%
# py-xgboost-1.5.1     | 151 KB    | ########## | 100%
#
# _py-xgboost-mutex-2. | 11 KB     |            |   0%
# _py-xgboost-mutex-2. | 11 KB     | ########## | 100%
# _py-xgboost-mutex-2. | 11 KB     | ########## | 100%
#
# libxgboost-1.5.1     | 2.3 MB    |            |   0%
# libxgboost-1.5.1     | 2.3 MB    | #####      |  50%
# libxgboost-1.5.1     | 2.3 MB    | ########## | 100%
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# libxgboost-1.5.1     | 2.3 MB    | ########## | 100%
#
# python_abi-3.9       | 4 KB      |            |   0%
# python_abi-3.9       | 4 KB      | ########## | 100%
# python_abi-3.9       | 4 KB      | ########## | 100%
#
# conda-4.13.0         | 1.0 MB    |            |   0%
# conda-4.13.0         | 1.0 MB    | ########## | 100%
# conda-4.13.0         | 1.0 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# implementing XGBoost regressor
import xgboost
classifier=xgboost.XGBRegressor()
classifier.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
import pickle
filename = "finalazied_model.plk"
pickle.dump(classifier,open(filename,'wb'))

# %%
# predicting the house prices
y_predict = classifier.predict(X_test)

# %%
# RMSE Computation
from sklearn.metrics import mean_squared_error as MSE
rmse = np.sqrt(MSE(y_test, y_predict))
print("RMSE : % f" %(rmse))
print("R^2:", metrics.r2_score(y_test, y_predict))
# Out:
# RMSE :  0.386051
# R^2: 0.7746062590189612

# %% [markdown]
# # Hyperparameter tuning

# %%
regressor=xgboost.XGBRegressor()
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]

## Hyper Parameter Optimization

n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]

learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]

# Defining the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
# Set up the random search with 4-fold cross validation
from sklearn.model_selection import RandomizedSearchCV

regressor = xgboost.XGBRegressor()
random_cv = RandomizedSearchCV(estimator=regressor,
            param_distributions=hyperparameter_grid,
            cv=5, n_iter=10,
            scoring = 'neg_mean_absolute_error',n_jobs = 4,
            verbose = 5, 
            return_train_score = True,
            random_state=42)

# %%
random_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           enable_categorical=False, gamma=None,
#                                           gpu_id=None, importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None,
#                                           max_delta_step=None, max_depth=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=...
#                                           tree_method=None,
#                                           validate_parameters=None,
#                                           verbosity=None),
#                    n_jobs=4,
#                    param_distributions={'base_score': [0.25, 0.5, 0.75, 1],
#                                         'booster': ['gbtree', 'gblinear'],
#                                         'learning_rate': [0.05, 0.1, 0.15, 0.2],
#                                         'max_depth': [2, 3, 5, 10, 15],
#                                         'min_child_weight': [1, 2, 3, 4],
#                                         'n_estimators': [100, 500, 900, 1100,
#                                                          1500]},
#                    random_state=42, return_train_score=True,
#                    scoring='neg_mean_absolute_error', verbose=5)

# %%
# finding the best estimate
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.15, max_delta_step=0,
#              max_depth=15, min_child_weight=4, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %% [markdown]
# # XGBoost implementation with tuned hyperparameters

# %%
# substituting the best parameters
regressor=xgboost.XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
             importance_type=None, interaction_constraints='',
             learning_rate=0.15, max_delta_step=0, max_depth=15,
             min_child_weight=4, monotone_constraints='()',
             n_estimators=100, n_jobs=8, num_parallel_tree=1, predictor='auto',random_state=0,
             reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
             tree_method='exact', validate_parameters=1, verbosity=None)

# %%
regressor.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.15, max_delta_step=0,
#              max_depth=15, min_child_weight=4, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_predict_tuned = regressor.predict(X_test)

# %%
# RMSE Computation for tuned model
from sklearn.metrics import mean_squared_error as MSE
rmse = np.sqrt(MSE(y_test, y_predict_tuned))
print("RMSE : % f" %(rmse))
print("R^2:", metrics.r2_score(y_test, y_predict_tuned))
# Out:
# RMSE :  0.364886
# R^2: 0.7986426607959669
